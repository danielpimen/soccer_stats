# %%
import pandas as pd 
import ScraperFC as sfc
# Out:
# C:\Users\danie\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
scraper = sfc.FBRef()
test = scraper.scrape_league_table(2015, 'EPL')
test
# Out:
# Scraping 2015 EPL league table
#     Rk            Squad   team_id  MP   W   D   L  GF  GA  GD  Pts  \
# 0    1          Chelsea  cff3d9bb  38  26   9   3  73  32  41   87
# 1    2  Manchester City  b8fd03ef  38  24   7   7  83  38  45   79
# 2    3          Arsenal  18bb7c10  38  22   9   7  71  36  35   75
# 3    4   Manchester Utd  19538871  38  20  10   8  62  37  25   70
# 4    5        Tottenham  361ca564  38  19   7  12  58  53   5   64
# 5    6        Liverpool  822bd0ba  38  18   8  12  52  48   4   62
# 6    7      Southampton  33c895d4  38  18   6  14  54  33  21   60
# 7    8     Swansea City  fb10988f  38  16   8  14  46  49  -3   56
# 8    9       Stoke City  17892952  38  15   9  14  48  45   3   54
# 9   10   Crystal Palace  47c64c55  38  13   9  16  47  51  -4   48
# 10  11          Everton  d3fd31cc  38  12  11  15  48  50  -2   47
# 11  12         West Ham  7c21e445  38  12  11  15  44  47  -3   47
# ...

# %%
df2015 = pd.DataFrame(test)
df2015.head()
df2015.to_csv('df2015.csv')

# %%
#test = scraper.scrape_league_table(2015, 'EPL')
##For Loop to pull decide how many years to pull 

##Last 5 years
from datetime import datetime
currentYear = datetime.now().year
num_of_years = 5 
set_year = 2021

test_list = []
yes = 5 

def epl_previous_five(): 
    set_year = 2021
    

    for x in range(num_of_years):
        set_year_int = set_year
        table = scraper.scrape_league_table(set_year_int, 'EPL')
        df_table = pd.DataFrame(table)
        name = str(set_year_int)
        filename = "%s.csv" % name
        filepath = "./data/league_tables/epl/{}".format(filename)

        df_table.to_csv(filepath)
    
        print(set_year_int)
        print('pulled')
        set_year = set_year - 1

# %%
epl_previous_five()
# Out:
# Scraping 2021 EPL league table
# 2021
# pulled
# Scraping 2020 EPL league table
# 2020
# pulled
# Scraping 2019 EPL league table
# 2019
# pulled
# Scraping 2018 EPL league table
# 2018
# pulled
# Scraping 2017 EPL league table
# 2017
# pulled
